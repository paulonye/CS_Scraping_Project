# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#                    CompanyName                             ProductID  \
# 0       Girlfriend collective   002d988b-2e4d-4d95-b36a-e6026c8f9402
# 1        Girlfriend collective  002d988b-2e4d-4d95-b36a-e6026c8f9402
# 2        Girlfriend collective  002d988b-2e4d-4d95-b36a-e6026c8f9402
# 3        Girlfriend collective  002d988b-2e4d-4d95-b36a-e6026c8f9402
# 4        Girlfriend collective  002d988b-2e4d-4d95-b36a-e6026c8f9402
# ...                        ...                                   ...
# 102073       Kanemasa Knitting  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102074       Kanemasa Knitting  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102075       Kanemasa Knitting  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102076       Kanemasa Knitting  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102077       Kanemasa Knitting  d41c3258-7509-40fd-8c00-8a27e49e600e
#
#                            ProductName          SKU  Index  \
# 0       Compressive Legging Long Black     0021_820      1
# 1       Compressive Legging Long Black     0021_820      2
# 2       Compressive Legging Long Black     0021_820      3
# 3       Compressive Legging Long Black     0021_820      4
# 4       Compressive Legging Long Black     0021_820      5
# ...                                ...          ...    ...
# 102073             Triple Color Stripe  CS-2fb30d1b      4
# 102074             Triple Color Stripe  CS-2fb30d1b      5
# 102075             Triple Color Stripe  CS-2fb30d1b      6
# 102076             Triple Color Stripe  CS-2fb30d1b      7
# 102077             Triple Color Stripe  CS-2fb30d1b      8
#
#                                                       URL  \
# 0       https://girlfriend.com/products/black-compress...
# 1             https://girlfriend.com/collections/leggings
# 2       https://girlfriend.com/products/black-compress...
# 3       https://girlfriend.com/products/black-compress...
# 4       https://girlfriend.com/products/black-compress...
# ...                                                   ...
# 102073  https://www.woolmark.com/globalassets/_06-new-...
# 102074     https://www.abtrs.com/11396cttt7df745uc90bbf11
# 102075       https://www.abtrs.com/36834uynk28479en56a194
# 102076  https://www.persuasion.ie/20661oybm55e638dty7d...
# 102077  https://blog.tincanknits.com/2021/01/07/stripe...
#
#                                                     Title
# 0       Black Compressive High-Rise Legging - Girlfrie...
# 1                        Leggings - Girlfriend Collective
# 2       Black Compressive Pocket Legging - Girlfriend ...
# 3                    Black Compressive Drawstring Legging
# 4       Black Compressive Flare Legging - Girlfriend C...
# ...                                                   ...
# 102073                  WOOL SOURCING GUIDE JAPAN EDITION
# 102074   立憲民主党 exclusive SHIRT KNIT KANEMASA 【最安値】+81 ...
# 102075            大特価祭 kanemasa カネマサ +81 ストライプシャツ グレー ...
# 102076            首相官邸 【最安値】+81別注 KANEMASA KNIT SHIRT ...
# 102077           Stripes Stripes Stripes! - Tin Can Knits
#
# [102078 rows x 7 columns]

# %%
data.dtypes
# Out:
# CompanyName    object
# ProductID      object
# ProductName    object
# SKU            object
# Index           int64
# URL            object
# Title          object
# dtype: object

# %%
data = data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
data['Target'] = data['CompanyName']+' '+data['ProductName']

# %%
data = data[['CompanyName', 'ProductName', 'ProductID', 'Target']]

# %%
data.duplicated().any()
# Out:
# True

# %%
duplicate_rows = data[data.duplicated()]
duplicate_rows
# Out:
#                   CompanyName                     ProductName  \
# 1       Girlfriend collective  Compressive Legging Long Black
# 2       Girlfriend collective  Compressive Legging Long Black
# 3       Girlfriend collective  Compressive Legging Long Black
# 4       Girlfriend collective  Compressive Legging Long Black
# 5       Girlfriend collective  Compressive Legging Long Black
# ...                       ...                             ...
# 102073      Kanemasa Knitting             Triple Color Stripe
# 102074      Kanemasa Knitting             Triple Color Stripe
# 102075      Kanemasa Knitting             Triple Color Stripe
# 102076      Kanemasa Knitting             Triple Color Stripe
# 102077      Kanemasa Knitting             Triple Color Stripe
#
#                                    ProductID  \
# 1       002d988b-2e4d-4d95-b36a-e6026c8f9402
# 2       002d988b-2e4d-4d95-b36a-e6026c8f9402
# 3       002d988b-2e4d-4d95-b36a-e6026c8f9402
# 4       002d988b-2e4d-4d95-b36a-e6026c8f9402
# 5       002d988b-2e4d-4d95-b36a-e6026c8f9402
# ...                                      ...
# 102073  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102074  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102075  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102076  d41c3258-7509-40fd-8c00-8a27e49e600e
# 102077  d41c3258-7509-40fd-8c00-8a27e49e600e
#
#                                                    Target
# 1       Girlfriend collective Compressive Legging Long...
# 2       Girlfriend collective Compressive Legging Long...
# 3       Girlfriend collective Compressive Legging Long...
# 4       Girlfriend collective Compressive Legging Long...
# 5       Girlfriend collective Compressive Legging Long...
# ...                                                   ...
# 102073              Kanemasa Knitting Triple Color Stripe
# 102074              Kanemasa Knitting Triple Color Stripe
# 102075              Kanemasa Knitting Triple Color Stripe
# 102076              Kanemasa Knitting Triple Color Stripe
# 102077              Kanemasa Knitting Triple Color Stripe
#
# [92197 rows x 4 columns]

# %%
new_data = data.drop_duplicates(keep = 'first')
new_data
# Out:
#                    CompanyName  \
# 0        Girlfriend collective
# 9                  Sam Edelman
# 10                        ABLE
# 11               Cashmere Duck
# 13              A.W.A.K.E Mode
# ...                        ...
# 102048  Karma Kokteyl Knitting
# 102056         Korukcu Tekstil
# 102057                    Rifo
# 102062                   Lcbio
# 102070       Kanemasa Knitting
#
#                                              ProductName  \
# 0                         Compressive Legging Long Black
# 9                Women's Jade Two-Piece Platform Sandals
# 10                                           EMMA BLOUSE
# 11                                Little Pickle Babygrow
# 13                     Shoulder Cut-Out Asymmetric Dress
# ...                                                  ...
# 102048                                            VIKO 1
# 102056                                       AC04175Y-02
# 102057       Recycled Cashmere Headbands Woman Antonella
# 102062  Red camellia (Camellia red) - youthfulness serum
# 102070                               Triple Color Stripe
#
#                                    ProductID  \
# 0       002d988b-2e4d-4d95-b36a-e6026c8f9402
# 9       004544a4-0863-46db-aed1-5695f6c14bd9
# 10      00f630f1-3a96-4f37-a652-ca53ecc534d6
# 11      0130ce77-ae7b-460f-89c6-9f81624ed9f1
# 13      018afe64-56bc-4ec1-9abb-59228ce6b235
# ...                                      ...
# 102048  d3cb3b82-eb1a-412a-afd4-bb7470fc055a
# 102056  d3e0a840-6ef2-4ec3-a9a5-94b64ba5d9b3
# 102057  d40be1c0-9e68-4b46-ae3b-e4d62f06ecae
# 102062  d412df96-6ee0-440a-8a3d-40d665d8293c
# 102070  d41c3258-7509-40fd-8c00-8a27e49e600e
#
#                                                    Target
# 0       Girlfriend collective Compressive Legging Long...
# 9       Sam Edelman Women's Jade Two-Piece Platform Sa...
# 10                                       ABLE EMMA BLOUSE
# 11                   Cashmere Duck Little Pickle Babygrow
# 13       A.W.A.K.E Mode Shoulder Cut-Out Asymmetric Dress
# ...                                                   ...
# 102048                      Karma Kokteyl Knitting VIKO 1
# 102056                        Korukcu Tekstil AC04175Y-02
# 102057   Rifo Recycled Cashmere Headbands Woman Antonella
# 102062  Lcbio Red camellia (Camellia red) - youthfulne...
# 102070              Kanemasa Knitting Triple Color Stripe
#
# [9881 rows x 4 columns]

# %%
new_data.to_csv('new_data.csv', index = False)

# %% [markdown]
# ## Code for Scrape

# %%
from bs4 import BeautifulSoup
import requests
import time
import random
from time import sleep
import pandas as pd



df1 = new_data[0:1000].reset_index().drop(['index'], axis = 1)
df1['new_url'] = None

try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")




USER_AGENTS = [
   #Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36']


count = 0
for i in range(len(df1['CompanyName'])):
    print(i)
    random_header = USER_AGENTS[random.randint(0,5)]
    try:
        for j in search("{}".format(df1['Target'][i]), tld="co.in", num=1, stop=1, pause=random.uniform(30,60)
                        ,lang='en',user_agent= random_header):
            print(random_header)
            print('{} - {}'.format(df1['Target'][i], j))       
            df1['new_url'][i] = j

    except Exception as e:
        print(e)
        df1['new_url'][i] = None
        sleep(5)
        continue
             
    count = count + 1
    if count > 20:
        sleep(20)
        count = 0
    else:
        pass    

df1.to_csv('res1.csv', index = False)
# Out:
# 0
# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36
# Girlfriend collective  Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 1
# /tmp/ipykernel_615839/2696686355.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['new_url'][i] = j
# Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 2
# Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 3
# Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 4
# Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 5
# Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 6
# Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# Girlfriend collective Compressive Legging Long Black - https://girlfriend.com/products/black-compressive-high-rise-legging
# 7
